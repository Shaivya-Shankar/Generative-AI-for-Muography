# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
    
import os
import sys
src_path = os.path.abspath('../src/')
if src_path not in sys.path:
    sys.path.append(src_path)
from annealing import *

plot_annealing(
    150,
    annealings = {
        'constant' : ConstantAnnealing(),
        'linear' : LinearAnnealing(T=100),
        'Cosine' : CosineAnnealing(T=100),
        'Sigmoid (k=0.1)' : SigmoidAnnealing(T=100,k=0.1),
        'Sigmoid (k=1)' : SigmoidAnnealing(T=100,k=1),
        'Sigmoid (k=5)' : SigmoidAnnealing(T=100,k=5),
        'Exponential (k=0.1)' : ExponentialAnnealing(k=0.1),
        'Exponential (k=1)' : ExponentialAnnealing(k=1.),
        'Exponential (k=5)' : ExponentialAnnealing(k=5.),
        'Cyclic (C=20,R=10)' : CyclicAnnealing(C=20,R=10),
    }
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
